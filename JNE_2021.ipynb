# %% [markdown]
# <a href="https://colab.research.google.com/github/CamilaAvila13/JNE/blob/main/JNE_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://github.com/CamilaAvila13/JNE/raw/refs/heads/main/EG2021_2V_Resultados_Presidencial.xlsx
# Out:
# --2026-05-19 22:36:20--  https://github.com/CamilaAvila13/JNE/raw/refs/heads/main/EG2021_2V_Resultados_Presidencial.xlsx
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/CamilaAvila13/JNE/refs/heads/main/EG2021_2V_Resultados_Presidencial.xlsx [following]
# --2026-05-19 22:36:20--  https://raw.githubusercontent.com/CamilaAvila13/JNE/refs/heads/main/EG2021_2V_Resultados_Presidencial.xlsx
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 74784 (73K) [application/octet-stream]
# Saving to: ‘EG2021_2V_Resultados_Presidencial.xlsx.2’
#
# ...

# %%
# !pip install pyreadstat

import pyreadstat
import pandas as pd

# Read the excel file, specifying header=4 so the 5th row (index 4) becomes the first row of the DataFrame
df = pd.read_excel("EG2021_2V_Resultados_Presidencial.xlsx.1")

df.head()
# Out:
# ...
#      Region    Provincia  Electores  Participación  % Participación  \
# 0  AMAZONAS  CHACHAPOYAS      40752          28447           0.6981
# 1  AMAZONAS  CHACHAPOYAS      40752          28447           0.6981
# 2  AMAZONAS  CHACHAPOYAS      40752          28447           0.6981
# 3  AMAZONAS  CHACHAPOYAS      40752          28447           0.6981
# 4  AMAZONAS        BAGUA      62110          38970           0.6274
#
#    Ausentismo  % Ausentismo  Votos emitidos  % Votos emitidos  Votos válidos  \
# 0       12305        0.3019           28447            0.6981          26144
# 1       12305        0.3019           28447            0.6981          26144
# 2       12305        0.3019           28447            0.6981          26144
# 3       12305        0.3019           28447            0.6981          26144
# 4       23140        0.3726           38970            0.6274          36750
#
#    % Votos válidos                 Organización Política  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 784 entries, 0 to 783
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Region                      784 non-null    object
#  1   Provincia                   784 non-null    object
#  2   Electores                   784 non-null    int64
#  3   Participación               784 non-null    int64
#  4   % Participación             784 non-null    float64
#  5   Ausentismo                  784 non-null    int64
#  6   % Ausentismo                784 non-null    float64
#  7   Votos emitidos              784 non-null    int64
#  8   % Votos emitidos            784 non-null    float64
#  9   Votos válidos               784 non-null    int64
#  10  % Votos válidos             784 non-null    float64
#  11  Organización Política       784 non-null    object
#  12  Tipo Organización Política  392 non-null    object
# ...

# %%
columns_to_drop = ['Region', 'Provincia', 'Electores', 'Participación','% Participación','Ausentiso', '% Ausentismo', 'Votos emitidos','% Votos emitidos', 'Votos válidos', '% Votos válidos', 'Ausentismo','Organización Política', 'Tipo Organización Política']
df = df.drop(columns=columns_to_drop, errors='ignore')
display(df.head())
# Out:
#    Votos  % Votos
# 0  10473   0.4006
# 1  15671   0.5994
# 2    274   0.0105
# 3   2029   0.0776
# 4  10770   0.2931

# %%
df.to_excel('Data_Camila_subset.xlsx', index=False)
print('DataFrame saved to Data_Camila_subset.xlsx')
# Out:
# DataFrame saved to Data_Camila_subset.xlsx

# %%
from google.colab import files
files.download('Data_Camila_subset.xlsx')
